# %%
import pandas as pd

# %%
data={"Name":["Alice","Bob","Carol"],"Age":[25,32,29],"Salary":[50000,70000,65000]}
df=pd.DataFrame(data)
df
# Out:
#     Name  Age  Salary
# 0  Alice   25   50000
# 1    Bob   32   70000
# 2  Carol   29   65000

# %%
df["Age"] #from this DataFrame called df give me the column labeled Age
# Out:
# 0    25
# 1    32
# 2    29
# Name: Age, dtype: int64

# %%
df["Salary"] #from this DataFrame called df give the column known as Salary.
# Out:
# 0    50000
# 1    70000
# 2    65000
# Name: Salary, dtype: int64

# %%
df["Name"]
# Out:
# 0    Alice
# 1      Bob
# 2    Carol
# Name: Name, dtype: str
